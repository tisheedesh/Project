# %% [markdown]
# # **Предобработка данных**

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/tisheedesh/Project/main/Data/data.csv').drop(['Unnamed: 0'], axis = 1)
# Out:
# <ipython-input-255-63b11c8ee372>:1: DtypeWarning: Columns (118) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('https://raw.githubusercontent.com/tisheedesh/Project/main/Data/data.csv').drop(['Unnamed: 0'], axis = 1)

# %% [markdown]
# > Исследуемый датасет - информация о кольцах с сайта ювелирной компании [SOKOLOV](https://sokolov.ru/), которые мы получили при помощи парсинга. Сам парсинг в файле parser.

# %%
data.head()
# Out:
#      Артикул    Бренд    Для кого Примерный вес   Тип металла  Проба  \
# 0  1012159-3  SOKOLOV  Для женщин        1.66 г  Белое золото  585.0
# 1    1011493  SOKOLOV  Для женщин        1.35 г  Белое золото  585.0
# 2  1012584-3  SOKOLOV  Для женщин         0.9 г  Белое золото  585.0
# 3    1011116  SOKOLOV  Для женщин        2.28 г  Белое золото  585.0
# 4  1011545-3  SOKOLOV  Для женщин        1.31 г  Белое золото  585.0
#
#       Покрытие            Тип вставки Форма вставки Количество  ... Чистота 6  \
# 0  Родирование  Бриллиант (природный)          Круг       6 шт  ...       NaN
# 1  Родирование  Бриллиант (природный)          Круг       1 шт  ...       NaN
# 2  Родирование  Бриллиант (природный)          Круг      23 шт  ...       NaN
# 3          NaN  Бриллиант (природный)          Круг       1 шт  ...       NaN
# 4  Родирование  Бриллиант (природный)          Круг      57 шт  ...       NaN
#
#   Цветность 7  Чистота 7  Огранка 5 Цветность 8 Чистота 8 Цветность 9  \
# 0         NaN        NaN        NaN         NaN       NaN         NaN
# 1         NaN        NaN        NaN         NaN       NaN         NaN
# 2         NaN        NaN        NaN         NaN       NaN         NaN
# 3         NaN        NaN        NaN         NaN       NaN         NaN
# 4         NaN        NaN        NaN         NaN       NaN         NaN
#
#   Чистота 9 Цветность 10 Чистота 10
# 0       NaN          NaN        NaN
# 1       NaN          NaN        NaN
# 2       NaN          NaN        NaN
# 3       NaN          NaN        NaN
# 4       NaN          NaN        NaN
#
# [5 rows x 124 columns]

# %% [markdown]
# ## **Описание признаков**

# %%
print(f'Названия колонок: \n {np.array(data.columns[:32])}')
# Out:
# Названия колонок:
#  ['Артикул' 'Бренд' 'Для кого' 'Примерный вес' 'Тип металла' 'Проба'
#  'Покрытие' 'Тип вставки' 'Форма вставки' 'Количество' 'Цвет' 'Вес'
#  'Цветность' 'Чистота' 'Огранка' 'Тип вставки 2' 'Форма вставки 2'
#  'Количество 2' 'Цвет 2' 'Вес 2' 'Цветность 2' 'Чистота 2' 'Огранка 2'
#  'Цена со скидкой' 'Цена без скидки' 'Номер страницы' 'Ширина кольца'
#  'Ширина' 'Высота' 'Длина' 'Размеры вставки' 'Коллекция']

# %% [markdown]
# В датасете 124 колонки.
#
# Для каждого кольца есть характеристики:
#
# * `Артикул` - артикул кольца на сайте.
# * `Бренд` - бренд кольца (здесь - у всех SOKOLOV).
# * `Для кого` - для кого предназначено кольцо (пол, возраст).
# * `Примерный вес` - вес кольца в граммах.
# * `Тип металла` - из какого металла сделано кольцо.
# * `Проба` - процент содержания драгоценного камня в сплаве (где 1000 - 100%).
# * `Покрытие` - специальная обработка для увеличения срока годности изделия и изменения внешнего вида путем покрытия металла другим металлом.
# * `Номер страницы` - так как кольца были отсортированы по полулярности, мы подумали, что можно как-то связать номер страницы (может выступать измерителем популярности кольца) с чем-либо еще. Данную гипотезу проверим позже.
# * `Ширина кольца` - ширина самого кольца без вставки.
# * `Ширина` - ширина кольца с учетом вставки.
# * `Высота` - высотка вставки.
# * `Длина` - длина вставки.
# * `Коллекция` - в основном какие-то коллаборации (например, SOKOLOV x LOLITA).
# * `Цена со скидкой`, `Цена без скидки` - целевые переменные (будет выбрана только одна для предсказания)
#
# \
# У каждого кольца есть от одной до 14 вставок драгоценных камней. Мы вынесли все 14 типов вставок как отдельные признаки (столбцы `Тип вставки`), причем у каждой вставки есть свои признаки:
# * `Форма вставки` - какой формы вставка драгоценного(-ых) камня(-ей).
# * `Количество` - количество камней в данной вставке.
# * `Цвет` - цвет камня.
# * `Вес` - вес всех камней во вставке (в каратах, 1 карат = 0.2 г)
# * `Цветность` - порядковая характеристика: чем меньше число, тем прозрачнее и ценнее камень.
# * `Чистота` - порядковая характеристика: чем меньше число, тем лувчше и ценнее камень
# * `Огранка` - порядковая характеристика механической обработки камня: `А` - очень хорошая, `Б` - хорошая, `В` - средняя, `Г` - плохая.
# * `Размеры вставки` - ширина вставки.

# %% [markdown]
# >### Шаг 1. Проверка дубликатов

# %% [markdown]
# Проверяем наличие дубликатов: полных дубликатов нет.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Однако количество уникальных артикулов не совпадает с количеством колец, что странно, ведь артикул у каждого кольца один.

# %%
print(f'Кол-во уникальных артикулов: {data.Артикул.nunique()} \nКол-во колец: {data.shape[0]}')
# Out:
# Кол-во уникальных артикулов: 10209
# Кол-во колец: 10216

# %% [markdown]
# Посмотрим, в чем различия колец с одинаковыми артикулами.

# %%
articles = data[data['Артикул'].duplicated()]['Артикул'].values
indexes = np.array([])
for elem in articles:
    display(data.loc[data['Артикул'] == elem])
    indexes = np.append(indexes, data.loc[data['Артикул'] == elem].index)
# Out:
#     Артикул    Бренд    Для кого Примерный вес     Тип металла  Проба  \
# 960  716327  SOKOLOV  Для женщин        1.51 г  Красное золото  585.0
# 961  716327  SOKOLOV  Для женщин        1.51 г  Красное золото  585.0
#
#         Покрытие Тип вставки Форма вставки Количество  ... Чистота 6  \
# 960  Родирование      Корунд         Груша       1 шт  ...       NaN
# 961  Родирование      Корунд         Груша       1 шт  ...       NaN
#
#     Цветность 7  Чистота 7  Огранка 5 Цветность 8 Чистота 8 Цветность 9  \
# 960         NaN        NaN        NaN         NaN       NaN         NaN
# 961         NaN        NaN        NaN         NaN       NaN         NaN
#
#     Чистота 9 Цветность 10 Чистота 10
# 960       NaN          NaN        NaN
# 961       NaN          NaN        NaN
#
# [2 rows x 124 columns]
#      Артикул    Бренд    Для кого Примерный вес     Тип металла  Проба  \
# 1603  716335  SOKOLOV  Для женщин        2.67 г  Красное золото  585.0
# 1604  716335  SOKOLOV  Для женщин        2.67 г  Красное золото  585.0
#
#      Покрытие Тип вставки Форма вставки Количество  ... Чистота 6 Цветность 7  \
# 1603      NaN   Празиолит       Октагон       1 шт  ...       NaN         NaN
# 1604      NaN   Празиолит       Октагон       1 шт  ...       NaN         NaN
#
#       Чистота 7  Огранка 5 Цветность 8 Чистота 8 Цветность 9 Чистота 9  \
# 1603        NaN        NaN         NaN       NaN         NaN       NaN
# 1604        NaN        NaN         NaN       NaN         NaN       NaN
#
#      Цветность 10 Чистота 10
# 1603          NaN        NaN
# 1604          NaN        NaN
#
# [2 rows x 124 columns]
#       Артикул    Бренд    Для кого Примерный вес             Тип металла  \
# 1890  1012013  SOKOLOV  Для женщин        2.04 г  Комбинированное золото
# 1891  1012013  SOKOLOV  Для женщин        2.04 г  Комбинированное золото
#
#       Проба     Покрытие            Тип вставки Форма вставки Количество  ...  \
# 1890  585.0  Родирование  Бриллиант (природный)          Круг      21 шт  ...
# 1891  585.0  Родирование  Бриллиант (природный)          Круг      21 шт  ...
#
#      Чистота 6 Цветность 7  Чистота 7  Огранка 5 Цветность 8 Чистота 8  \
# 1890       NaN         NaN        NaN        NaN         NaN       NaN
# 1891       NaN         NaN        NaN        NaN         NaN       NaN
#
#      Цветность 9 Чистота 9 Цветность 10 Чистота 10
# 1890         NaN       NaN          NaN        NaN
# 1891         NaN       NaN          NaN        NaN
#
# [2 rows x 124 columns]
#        Артикул    Бренд    Для кого Примерный вес           Тип металла  \
# 2231  94011336  SOKOLOV  Для женщин        1.72 г  Родированное серебро
# 2232  94011336  SOKOLOV  Для женщин        1.72 г  Родированное серебро
#
#       Проба Покрытие Тип вставки Форма вставки Количество  ... Чистота 6  \
# 2231  925.0    Эмаль      Фианит          Круг      16 шт  ...       NaN
# 2232  925.0    Эмаль      Фианит          Круг      16 шт  ...       NaN
#
#      Цветность 7  Чистота 7  Огранка 5 Цветность 8 Чистота 8 Цветность 9  \
# 2231         NaN        NaN        NaN         NaN       NaN         NaN
# 2232         NaN        NaN        NaN         NaN       NaN         NaN
#
#      Чистота 9 Цветность 10 Чистота 10
# 2231       NaN          NaN        NaN
# 2232       NaN          NaN        NaN
#
# [2 rows x 124 columns]
#        Артикул    Бренд    Для кого Примерный вес           Тип металла  \
# 2374  94013377  SOKOLOV  Для женщин        1.29 г  Родированное серебро
# 2375  94013377  SOKOLOV  Для женщин        1.29 г  Родированное серебро
#
#       Проба Покрытие Тип вставки Форма вставки Количество  ... Чистота 6  \
# 2374  925.0      NaN      Фианит          Круг      24 шт  ...       NaN
# 2375  925.0      NaN      Фианит          Круг      24 шт  ...       NaN
#
#      Цветность 7  Чистота 7  Огранка 5 Цветность 8 Чистота 8 Цветность 9  \
# 2374         NaN        NaN        NaN         NaN       NaN         NaN
# 2375         NaN        NaN        NaN         NaN       NaN         NaN
#
#      Чистота 9 Цветность 10 Чистота 10
# 2374       NaN          NaN        NaN
# 2375       NaN          NaN        NaN
#
# [2 rows x 124 columns]
#      Артикул    Бренд    Для кого Примерный вес     Тип металла  Проба  \
# 3159  716001  SOKOLOV  Для женщин        3.15 г  Красное золото  585.0
# 3160  716001  SOKOLOV  Для женщин        3.15 г  Красное золото  585.0
#
#          Покрытие Тип вставки Форма вставки Количество  ... Чистота 6  \
# 3159  Родирование   Раухтопаз         Груша       1 шт  ...       NaN
# 3160  Родирование   Раухтопаз         Груша       1 шт  ...       NaN
#
#      Цветность 7  Чистота 7  Огранка 5 Цветность 8 Чистота 8 Цветность 9  \
# 3159         NaN        NaN        NaN         NaN       NaN         NaN
# 3160         NaN        NaN        NaN         NaN       NaN         NaN
#
#      Чистота 9 Цветность 10 Чистота 10
# 3159       NaN          NaN        NaN
# 3160       NaN          NaN        NaN
#
# [2 rows x 124 columns]
#      Артикул    Бренд    Для кого Примерный вес     Тип металла  Проба  \
# 829   017107  SOKOLOV  Для женщин         2.5 г  Красное золото  585.0
# 7078  017107  SOKOLOV  Для женщин         2.5 г  Красное золото  585.0
#
#                           Покрытие  Тип вставки Форма вставки Количество  ...  \
# 829   Алмазная грань,  Родирование  Без вставок           NaN        NaN  ...
# 7078  Алмазная грань,  Родирование  Без вставок           NaN        NaN  ...
#
#      Чистота 6 Цветность 7  Чистота 7  Огранка 5 Цветность 8 Чистота 8  \
# 829        NaN         NaN        NaN        NaN         NaN       NaN
# 7078       NaN         NaN        NaN        NaN         NaN       NaN
#
#      Цветность 9 Чистота 9 Цветность 10 Чистота 10
# 829          NaN       NaN          NaN        NaN
# 7078         NaN       NaN          NaN        NaN
#
# [2 rows x 124 columns]

# %%
for elem in articles:
    dubl = data.loc[data['Артикул'] == elem]
    display(dubl.iloc[0].compare(dubl.iloc[1]))
# Out:
#                self other
# Номер страницы   14    15
#                self other
# Номер страницы   23    24
#                self other
# Номер страницы   27    28
#                self other
# Номер страницы   34    35
#                self other
# Номер страницы   36    37
#                self other
# Номер страницы   47    48
#                self other
# Номер страницы   12   102

# %% [markdown]
# Каждый артикул повторяется только два раза, и различия лишь в номере страниц: возможно, во время парсинга кольцо переместилось с одной страницы на другую. Удаляем дубликаты.

# %%
for i in indexes[1::2]:
    data.drop(index = i, inplace=True)
data.reset_index(inplace=True)

# %% [markdown]
# > ### Шаг 2: работа с пропусками

# %% [markdown]
# В данном датасете очень много пропусков. Посмотрим на первые 32 колонки: есть какие-то отдельные признаки с большим количеством пропусков, с ними разберемся позже.

# %%
data.isna().sum()[:32]
# Out:
# index                  0
# Артикул                0
# Бренд                  0
# Для кого              27
# Примерный вес          9
# Тип металла            0
# Проба                 44
# Покрытие            3519
# Тип вставки            5
# Форма вставки       1111
# Количество           983
# Цвет                1123
# Вес                  987
# Цветность           6753
# Чистота             6747
# Огранка             9862
# Тип вставки 2       5086
# Форма вставки 2     5194
# Количество 2        5086
# Цвет 2              5211
# Вес 2               5088
# Цветность 2         8756
# Чистота 2           8739
# Огранка 2          10065
# Цена со скидкой        0
# Цена без скидки        0
# Номер страницы         0
# Ширина кольца       3939
# Ширина              5089
# Высота              5104
# Длина               7133
# Размеры вставки     4071
# dtype: int64

# %% [markdown]
# В последних колонках пропуски -  почти все строки. Так получилось из-за того, что мало колец с большим количеством вставок - их можно считать выбросами.

# %%
data.isna().sum().tail(20)
# Out:
# Размеры вставки 13    10206
# Тип вставки 14        10207
# Форма вставки 14      10207
# Количество 14         10207
# Цвет 14               10207
# Вес 14                10207
# Размеры вставки 14    10207
# Цветность 5           10192
# Чистота 5             10192
# Цветность 6           10203
# Чистота 6             10202
# Цветность 7           10203
# Чистота 7             10203
# Огранка 5             10208
# Цветность 8           10207
# Чистота 8             10207
# Цветность 9           10208
# Чистота 9             10208
# Цветность 10          10208
# Чистота 10            10208
# dtype: int64

# %% [markdown]
# Мы решили сузить объект исследования до колец без вставок и колец только с одной вставкой, так как у нас мало данных по кольцам с большим количеством вставок. Таким образом, мы немного ограничиваем нашу тему, при этом у нас остается достаточное количество данных.

# %%
nan_vst_3 = (data.isna().sum()['Тип вставки 2'])
print(f'Колец с количеством вставок менее двух {nan_vst_3} штук, всего колец {data.shape[0]}')
# Out:
# Колец с количеством вставок менее двух 5086 штук, всего колец 10209

# %% [markdown]
# Убираем строки, где `Тип вставки 2` не является `nan`.

# %%
data.drop(data[~data['Тип вставки 2'].isna()].index, inplace=True)
data.reset_index(inplace=True, drop=True)

# %%
data.drop('index', axis=1, inplace=True)

# %% [markdown]
# Также убираем столбцы, которые отвечают за типы вставок с более или равным второму порядку и за их признаки.

# %%
for title in data.columns:
    if title[-1].isnumeric():
        data.drop([title], axis=1, inplace=True)

# %%
data = data[['Артикул', 'Бренд', 'Коллекция', 'Для кого', 'Примерный вес', 'Тип металла', 'Проба',
            'Покрытие', 'Тип вставки', 'Форма вставки', 'Количество', 'Цвет', 'Вес',
            'Цветность', 'Чистота', 'Огранка', 'Размеры вставки', 'Ширина кольца', 'Ширина', 'Высота',
            'Длина', 'Номер страницы', 'Цена со скидкой', 'Цена без скидки']]

# %%
data.head()
# Out:
#      Артикул    Бренд Коллекция    Для кого Примерный вес     Тип металла  \
# 0    1011493  SOKOLOV       NaN  Для женщин        1.35 г    Белое золото
# 1  1012584-3  SOKOLOV       NaN  Для женщин         0.9 г    Белое золото
# 2  1011545-3  SOKOLOV       NaN  Для женщин        1.31 г    Белое золото
# 3     019243  SOKOLOV       NaN  Для женщин        0.99 г  Красное золото
# 4     019263  SOKOLOV       NaN  Для женщин        0.97 г  Красное золото
#
#    Проба     Покрытие            Тип вставки Форма вставки  ... Чистота  \
# 0  585.0  Родирование  Бриллиант (природный)          Круг  ...     6.0
# 1  585.0  Родирование  Бриллиант (природный)          Круг  ...     3.0
# 2  585.0  Родирование  Бриллиант (природный)          Круг  ...     3.0
# 3  585.0          NaN                 Фианит          Круг  ...     NaN
# 4  585.0  Родирование                 Фианит          Круг  ...     NaN
#
#   Огранка Размеры вставки  Ширина кольца  Ширина Высота  Длина Номер страницы  \
# 0     NaN             NaN            NaN     NaN    NaN    NaN              1
# 1       А             NaN           2 мм    2 мм   1 мм    NaN              1
# 2     NaN             NaN            NaN     NaN    NaN    NaN              1
# 3     NaN            5 мм           2 мм    5 мм   4 мм    NaN              1
# 4     NaN            3 мм           1 мм    3 мм   3 мм  15 мм              1
#
#   Цена со скидкой Цена без скидки
# 0           35100           77990
# 1            7990            7990
# 2           56250          124990
# 3            6990            6990
# 4            6490            6490
#
# [5 rows x 24 columns]

# %% [markdown]
# Получилось 24 колонки, однако мы не разобрались с упомянутыми в начале колонками, где много пустых значений. Поставим порог в 50% от всех колец и удалим колонки, в которых пустых значений больше порога.

# %%
nan_col = []
for i in range(len(data.isna().sum())):
    if data.isna().sum()[i] / data.shape[0] > 0.5:
        nan_col.append(data.isna().sum().index[i])
nan_col
# Out:
# ['Коллекция', 'Цветность', 'Чистота', 'Огранка', 'Размеры вставки', 'Длина']

# %% [markdown]
# Помимо выше упомянутых признаков, `Бренд` в данном датасете один - SOKOLOV, поэтому его тоже можно дропнуть.
#
# `Артикул` также не несет никакой информации, его необходимо удалить, но сделаем это в самом конце, так как по артикулу можно смотреть, какие конкретно кольца чем-либо выделяются.

# %%
data['Бренд'].unique()
# Out:
# array(['SOKOLOV'], dtype=object)

# %%
nan_col.append('Бренд')
data.drop(nan_col, axis=1, inplace=True)
data.head()
# Out:
#      Артикул    Для кого Примерный вес     Тип металла  Проба     Покрытие  \
# 0    1011493  Для женщин        1.35 г    Белое золото  585.0  Родирование
# 1  1012584-3  Для женщин         0.9 г    Белое золото  585.0  Родирование
# 2  1011545-3  Для женщин        1.31 г    Белое золото  585.0  Родирование
# 3     019243  Для женщин        0.99 г  Красное золото  585.0          NaN
# 4     019263  Для женщин        0.97 г  Красное золото  585.0  Родирование
#
#              Тип вставки Форма вставки Количество        Цвет          Вес  \
# 0  Бриллиант (природный)          Круг       1 шт  Бесцветный   0.03 карат
# 1  Бриллиант (природный)          Круг      23 шт  Бесцветный  0.069 карат
# 2  Бриллиант (природный)          Круг      57 шт  Бесцветный  0.165 карат
# 3                 Фианит          Круг       1 шт  Бесцветный  0.846 карат
# 4                 Фианит          Круг       5 шт  Бесцветный  1.004 карат
#
#   Ширина кольца Ширина Высота  Номер страницы  Цена со скидкой  \
# 0           NaN    NaN    NaN               1            35100
# 1          2 мм   2 мм   1 мм               1             7990
# 2           NaN    NaN    NaN               1            56250
# 3          2 мм   5 мм   4 мм               1             6990
# 4          1 мм   3 мм   3 мм               1             6490
#
#    Цена без скидки
# 0            77990
# 1             7990
# 2           124990
# 3             6990
# 4             6490

# %% [markdown]
# > ### Шаг 3: преобразование типов данных

# %% [markdown]
# В датасете присутствуют количественные признаки, однако они все в формате `str` (кроме пробы, номера страницы и цен), и многие с указанием единиц измерения. Нужно привести их к типу данных `float`.

# %%
data.dtypes
# Out:
# Артикул             object
# Для кого            object
# Примерный вес       object
# Тип металла         object
# Проба              float64
# Покрытие            object
# Тип вставки         object
# Форма вставки       object
# Количество          object
# Цвет                object
# Вес                 object
# Ширина кольца       object
# Ширина              object
# Высота              object
# Номер страницы       int64
# Цена со скидкой      int64
# Цена без скидки      int64
# dtype: object

# %%
num_col = ['Примерный вес', 'Количество', 'Вес', 'Ширина', 'Высота']
for col in num_col:
    data[col] = data[col].apply(lambda x: float(x.split()[0]) if type(x) == str else x)
data.head()
# Out:
#      Артикул    Для кого  Примерный вес     Тип металла  Проба     Покрытие  \
# 0    1011493  Для женщин           1.35    Белое золото  585.0  Родирование
# 1  1012584-3  Для женщин           0.90    Белое золото  585.0  Родирование
# 2  1011545-3  Для женщин           1.31    Белое золото  585.0  Родирование
# 3     019243  Для женщин           0.99  Красное золото  585.0          NaN
# 4     019263  Для женщин           0.97  Красное золото  585.0  Родирование
#
#              Тип вставки Форма вставки  Количество        Цвет    Вес  \
# 0  Бриллиант (природный)          Круг         1.0  Бесцветный  0.030
# 1  Бриллиант (природный)          Круг        23.0  Бесцветный  0.069
# 2  Бриллиант (природный)          Круг        57.0  Бесцветный  0.165
# 3                 Фианит          Круг         1.0  Бесцветный  0.846
# 4                 Фианит          Круг         5.0  Бесцветный  1.004
#
#   Ширина кольца  Ширина  Высота  Номер страницы  Цена со скидкой  \
# 0           NaN     NaN     NaN               1            35100
# 1          2 мм     2.0     1.0               1             7990
# 2           NaN     NaN     NaN               1            56250
# 3          2 мм     5.0     4.0               1             6990
# 4          1 мм     3.0     3.0               1             6490
#
#    Цена без скидки
# 0            77990
# 1             7990
# 2           124990
# 3             6990
# 4             6490

# %% [markdown]
# Отдельно преобразуем формат столбца `Ширина кольца`, так как в нем есть значение `'1. 6 мм'`, которое отформатируем отдельно.

# %%
data['Ширина кольца'].unique()
# Out:
# array([nan, '2 мм', '1 мм', '5 мм', '3 мм', '4 мм', '6 мм', '7 мм',
#        '8 мм', '11 мм', '9 мм', '12 мм', '15 мм', '10 мм', '13 мм',
#        '17 мм', '20 мм', '14 мм'], dtype=object)

# %%
data['Ширина кольца'] = data['Ширина кольца'].apply(lambda x: float(x.split()[0]) if (type(x) == str) and (x != '1, 6 мм') else x)
data.loc[data['Ширина кольца'] == '1, 6 мм', 'Ширина кольца'] = 1.6

# %% [markdown]
# С признаком `Размеры вставки` все сложнее: там очень разные характеристики. У одних камней дана длина и ширина, у других лишь ширина. Мы решили усреднить длину и ширину, так как вряд ли у камня они сильно будут различаться (обычно камни плюс минус симметричные)

# %%
data.dtypes
# Out:
# Артикул             object
# Для кого            object
# Примерный вес      float64
# Тип металла         object
# Проба              float64
# Покрытие            object
# Тип вставки         object
# Форма вставки       object
# Количество         float64
# Цвет                object
# Вес                float64
# Ширина кольца      float64
# Ширина             float64
# Высота             float64
# Номер страницы       int64
# Цена со скидкой      int64
# Цена без скидки      int64
# dtype: object

# %% [markdown]
# > ### Шаг 4: Заполняем пустые значения

# %% [markdown]
# Вернемся к `nan`, их у нас много, поэтому необходимо их по-умному заполнить.

# %%
data.isna().sum()
# Out:
# Артикул               0
# Для кого             10
# Примерный вес         9
# Тип металла           0
# Проба                40
# Покрытие           2009
# Тип вставки           5
# Форма вставки      1111
# Количество          983
# Цвет               1119
# Вес                 987
# Ширина кольца      1875
# Ширина             2385
# Высота             2392
# Номер страницы        0
# Цена со скидкой       0
# Цена без скидки       0
# dtype: int64

# %% [markdown]
# 1. В столбцах `Для кого` и `Покрытие` заполним пропуски словом `Неизвестно`, так как нам никак не определить, для кого предназначается это кольцо по каким-либо признакам (быть может по отзывам/фото, но это слишком сложно), как и не определить покрытие без точного указания данного признака. Далее при кодировании данных признаков при помощи OHE можно будет удалить столбцы с названием `Неизвестно`.

# %%
print(data['Для кого'].unique())
print()
print(data['Покрытие'].unique())
# Out:
# ['Для женщин' 'Для женщин, Для мужчин, Унисекс' 'Для мужчин' 'Для детей'
#  nan 'Для женщин, Для мужчин, Для детей']
#
# ['Родирование' nan 'Алмазная грань,  Родирование' 'Алмазная грань'
#  'Золочение' 'Родирование,  Эмаль' 'Золочение,  Родирование' 'Эмаль'
#  'Гравировка,  Родирование' 'Золочение,  Эмаль' 'Гравировка'
#  'Золочение,  Родирование,  Эмаль' 'Гравировка,  Золочение'
#  'Лазерная обработка,  Родирование' 'Чернение'
#  'Алмазная грань,  Родирование,  Эмаль']

# %%
data[['Для кого', 'Покрытие']] = data[['Для кого', 'Покрытие']].fillna('Неизвестно')

# %% [markdown]
# 2. Пропуски в столбцах `Примерный вес`, `Ширина`, `Ширина кольца`, `Высота` заменим средними.

# %%
columns_nan = ['Примерный вес', 'Ширина кольца', 'Ширина', 'Высота']
data[columns_nan] = data[columns_nan].fillna(data[columns_nan].mean())

# %% [markdown]
# 3. `Проба` - заменим средними в зависимости от типа металла. Сначала найдём, сколько колец не имеют в описании пробы, а также металлы, из которых эти кольца сделаны:

# %%
data.loc[data['Проба'].isna(), 'Тип металла'].value_counts()
# Out:
# Тип металла
# Сталь      25
# Платина    15
# Name: count, dtype: int64

# %% [markdown]
# Пробу не имеют только стальные и платиновые кольца. В случае со сталью всё понятно - маркировка пробы ставится только у драгоценных металлов. В таком случае сделаем пробу стали равной 1000, что интерпретируется как "чистая сталь" (1000 мг стали в 1 грамме сплава). Это действие можно объяснить предпосылкой о том, что эластичность цены драгоценных металлов по их пробе выше, чем у недрагоценных.
#
# В случае с платиной неизвестно, почему отсутствует маркировка пробы. Исходя из сайта https://aquamarine.gold/blog/yuvelirnoe-probirovanie-na-serebre-platine-i-palladii/, можно поставить изделиям из платины 950 пробу.

# %%
data.loc[data['Тип металла'] == 'Сталь', 'Проба'] = 1000.0
data.loc[data['Тип металла'] == 'Платина', 'Проба'] = 950.0

# %% [markdown]
# 4. Далее переходим к вставкам. В столбце `Тип вставки` всего 5 пропущенных значений, посмотрим на них.
#
# Все эти кольца, если посмотреть на сайте, имеют специфические вставки: керамические, хромдиопси, поэтому их можно убрать из выборки (как выбросы).

# %%
data[data['Тип вставки'].isna()]
# Out:
#        Артикул    Для кого  Примерный вес           Тип металла  Проба  \
# 2163  94013741  Для женщин           0.17  Родированное серебро  925.0
# 2559    717010  Для женщин           1.60        Красное золото  585.0
# 2901    716396  Для женщин           2.59        Красное золото  585.0
# 2903    716405  Для женщин           1.23        Красное золото  585.0
# 3069  94013807  Для женщин           0.35  Родированное серебро  925.0
#
#         Покрытие Тип вставки Форма вставки  Количество Цвет  Вес  \
# 2163  Неизвестно         NaN           NaN         NaN  NaN  NaN
# 2559  Неизвестно         NaN           NaN         NaN  NaN  NaN
# 2901  Неизвестно         NaN           NaN         NaN  NaN  NaN
# 2903  Неизвестно         NaN           NaN         NaN  NaN  NaN
# 3069  Неизвестно         NaN           NaN         NaN  NaN  NaN
#
#       Ширина кольца    Ширина    Высота  Номер страницы  Цена со скидкой  \
# 2163            3.0  5.000000  4.000000              61             3820
# 2559            2.0  7.272492  3.373794              71            18000
# 2901            2.0  7.272492  3.373794              81            32850
# 2903            1.0  7.272492  3.373794              81            21600
# 3069            3.0  6.000000  4.000000              86             3820
#
#       Цена без скидки
# 2163             8490
# 2559            59990
# 2901            72990
# 2903            47990
# 3069             8490

# %%
data.drop(data[data['Тип вставки'].isna()].index, inplace=True)

# %% [markdown]
# Теперь в столбце `Тип вставки` остались сами типы вставок, а также значение `Без вставок`. У колец без камней можно заменить все категориальные признаки вставок на значение `Без вставок` (это `Форма вставки` и `Цвет`), а количественные - на `0` (это `Количество`, `Вес`).

# %%
data.columns
# Out:
# Index(['Артикул', 'Для кого', 'Примерный вес', 'Тип металла', 'Проба',
#        'Покрытие', 'Тип вставки', 'Форма вставки', 'Количество', 'Цвет', 'Вес',
#        'Ширина кольца', 'Ширина', 'Высота', 'Номер страницы',
#        'Цена со скидкой', 'Цена без скидки'],
#       dtype='object')

# %%
cat_vstavki =['Форма вставки', 'Цвет']
num_vstavki = ['Количество', 'Вес']
data.loc[data['Тип вставки'] == 'Без вставок', cat_vstavki] = data.loc[data['Тип вставки'] == 'Без вставок', cat_vstavki].fillna('Без вставок')
data.loc[data['Тип вставки'] == 'Без вставок', num_vstavki] = data.loc[data['Тип вставки'] == 'Без вставок', num_vstavki].fillna(0)

# %% [markdown]
# Оставшиеся пустые значения заменим на `Неизвестно` у качественных признаков, и на среднее у количественных

# %%
cat_ost = ['Форма вставки', 'Цвет']
num_ost = ['Вес']

data[cat_ost] = data[cat_ost].fillna('Неизвестно')
data[num_ost] = data[num_ost].fillna(data[num_ost].mean())
data.isna().sum()
# Out:
# Артикул            0
# Для кого           0
# Примерный вес      0
# Тип металла        0
# Проба              0
# Покрытие           0
# Тип вставки        0
# Форма вставки      0
# Количество         0
# Цвет               0
# Вес                0
# Ширина кольца      0
# Ширина             0
# Высота             0
# Номер страницы     0
# Цена со скидкой    0
# Цена без скидки    0
# dtype: int64

# %% [markdown]
# Сохраним преобразованные данные в отдельный файл:

# %%
data.to_csv('data_processed.csv')
